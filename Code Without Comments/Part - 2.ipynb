# %% [markdown]
# ## Imoport relevent libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Loading data

# %%
npz = np.load('Audibooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('Audibooks_data_validation.npz')

validation_inputs = npz['inputs'].astype(np.float)
validation_targets = npz['targets'].astype(np.int)

npz = np.load('Audibooks_data_test.npz')

test_inputs = npz['inputs'].astype(np.float)
test_targets = npz['targets'].astype(np.int)

# %% [markdown]
# ## Model

# %%
input_size = 10
output_size =2
hidden_layer_size = 50

model = tf.keras.Sequential([
    
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(output_size,activation='softmax')

])


model.compile(optimizer ='adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

batch_size = 100

max_epochs = 100

early_stopping =tf.keras.callbacks.EarlyStopping()

model.fit(train_inputs,train_targets,callbacks=[early_stopping],batch_size=batch_size,epochs = max_epochs,validation_data=(validation_inputs,validation_targets),validation_steps=1,verbose = 2)
# Out:
# Train on 3579 samples, validate on 447 samples
# Epoch 1/100
# 3579/3579 - 1s - loss: 0.5266 - accuracy: 0.8033 - val_loss: 0.0811 - val_accuracy: 0.9100
# Epoch 2/100
# 3579/3579 - 0s - loss: 0.3623 - accuracy: 0.8726 - val_loss: 0.0625 - val_accuracy: 0.9200
# Epoch 3/100
# 3579/3579 - 0s - loss: 0.3122 - accuracy: 0.8832 - val_loss: 0.0582 - val_accuracy: 0.9100
# Epoch 4/100
# 3579/3579 - 0s - loss: 0.2906 - accuracy: 0.8921 - val_loss: 0.0545 - val_accuracy: 0.9100
# Epoch 5/100
# 3579/3579 - 0s - loss: 0.2749 - accuracy: 0.8963 - val_loss: 0.0519 - val_accuracy: 0.9100
# Epoch 6/100
# 3579/3579 - 0s - loss: 0.2662 - accuracy: 0.8980 - val_loss: 0.0499 - val_accuracy: 0.9100
# Epoch 7/100
# 3579/3579 - 0s - loss: 0.2592 - accuracy: 0.9014 - val_loss: 0.0498 - val_accuracy: 0.9100
# Epoch 8/100
# 3579/3579 - 0s - loss: 0.2537 - accuracy: 0.9036 - val_loss: 0.0485 - val_accuracy: 0.9100
# Epoch 9/100
# ...

# %% [markdown]
# ## Test Model

# %%
test_loss,test_accuracy = model.evaluate(test_inputs,test_targets)
# Out:
# 448/1 [===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print('test_loss : {:.2f} . test_accuracy : {:.2f}%'.format(test_loss,test_accuracy*100))
# Out:
# test_loss : 0.24 . test_accuracy : 91.29%
